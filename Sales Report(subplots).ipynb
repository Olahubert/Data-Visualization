# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
pd.read_csv("sales.csv")
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
Sales=pd.read_csv("sales.csv")

# %%
Sales.head(20)
# Out:
#          State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0   California            63.0        Amaretto  109.0  Major Market  -131.0
# 1   California            55.0       Green Tea  201.0  Major Market    88.0
# 2   California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3   California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4   California            37.0       Chamomile  247.0  Major Market   148.0
# 5   California            99.0           Lemon  582.0  Major Market   291.0
# 6   California            25.0            Mint   90.0  Major Market    26.0
# 7   California            43.0      Darjeeling  276.0  Major Market   120.0
# 8   California            32.0       Earl Grey  187.0  Major Market    79.0
# 9   California           142.0       Columbian  687.0  Major Market   364.0
# 10  California           166.0       Columbian  902.0  Major Market   508.0
# ...

# %%
Sales1=Sales.head(20)

# %%
Sales.tail(20)
# Out:
#           State  Total Expenses         Product  Sales   Market Size  Profit  \
# 4221  Wisconsin            29.0  Decaf Espresso  115.0  Small Market    36.0
# 4222  Wisconsin            26.0  Decaf Espresso  110.0  Small Market    47.0
# 4223  Wisconsin            19.0  Decaf Espresso   55.0  Small Market    16.0
# 4224  Wisconsin            36.0       Chamomile  104.0  Small Market    29.0
# 4225  Wisconsin            41.0       Chamomile  151.0  Small Market    53.0
# 4226  Wisconsin            40.0       Chamomile  141.0  Small Market    48.0
# 4227  Wisconsin            36.0       Chamomile  107.0  Small Market    30.0
# 4228  Wisconsin            42.0       Chamomile  178.0  Small Market    93.0
# 4229  Wisconsin            36.0       Chamomile  114.0  Small Market    45.0
# 4230  Wisconsin            27.0           Lemon  144.0  Small Market    58.0
# 4231  Wisconsin            25.0           Lemon  123.0  Small Market    64.0
# ...

# %%
Sales2=Sales.tail(20)

# %%
Sales1["Total Expenses"]
# Out:
# 0      63.0
# 1      55.0
# 2     143.0
# 3     113.0
# 4      37.0
# 5      99.0
# 6      25.0
# 7      43.0
# 8      32.0
# 9     142.0
# 10    166.0
# 11    139.0
# 12     54.0
# 13    109.0
# 14    116.0
# 15    107.0
# 16     33.0
# 17     88.0
# 18     91.0
# 19     28.0
# Name: Total Expenses, dtype: float64

# %%
Total_expenses1=Sales1["Total Expenses"]

# %%
Sales1["Product Type"]
# Out:
# 0         Coffee
# 1            Tea
# 2       Espresso
# 3       Espresso
# 4     Herbal Tea
# 5     Herbal Tea
# 6     Herbal Tea
# 7            Tea
# 8            Tea
# 9         Coffee
# 10        Coffee
# 11        Coffee
# 12           Tea
# 13      Espresso
# 14      Espresso
# 15      Espresso
# 16    Herbal Tea
# 17    Herbal Tea
# 18    Herbal Tea
# 19    Herbal Tea
# Name: Product Type, dtype: object

# %%
Product_type1=Sales1["Product Type"]

# %%
Sales2["Total Expenses"]
# Out:
# 4221    29.0
# 4222    26.0
# 4223    19.0
# 4224    36.0
# 4225    41.0
# 4226    40.0
# 4227    36.0
# 4228    42.0
# 4229    36.0
# 4230    27.0
# 4231    25.0
# 4232    40.0
# 4233    38.0
# 4234    35.0
# 4235    33.0
# 4236    34.0
# 4237    36.0
# 4238    86.0
# 4239    79.0
# 4240    87.0
# Name: Total Expenses, dtype: float64

# %%
Total_expenses2=Sales2["Total Expenses"]

# %%
Sales2["Product Type"]
# Out:
# 4221      Espresso
# 4222      Espresso
# 4223      Espresso
# 4224    Herbal Tea
# 4225    Herbal Tea
# 4226    Herbal Tea
# 4227    Herbal Tea
# 4228    Herbal Tea
# 4229    Herbal Tea
# 4230    Herbal Tea
# 4231    Herbal Tea
# 4232           Tea
# 4233           Tea
# 4234           Tea
# 4235           Tea
# 4236           Tea
# 4237           Tea
# 4238           Tea
# 4239           Tea
# 4240           Tea
# Name: Product Type, dtype: object

# %%
Product_type2=Sales2["Product Type"]

# %%
fig, ax = plt.subplots(2,figsize =(20,20))     # Create a figure and a grid of subplots with 2 rows
fig.suptitle('Sale/Revenue', fontsize=14, fontweight='bold')  
ax[0].pie(Total_expenses1, labels=Product_type1, autopct="%.2f%%")
ax[1].pie(Total_expenses2, labels=Product_type2, autopct="%.2f%%")

ax[0].set_title("Total_expenses/Product_type1")
ax[1].set_title("Total_expenses2/Product_type2")

plt.show()

# %%
Sales['Product']
# Out:
# 0             Amaretto
# 1            Green Tea
# 2          Caffe Mocha
# 3       Decaf Espresso
# 4            Chamomile
#              ...
# 4236        Darjeeling
# 4237        Darjeeling
# 4238         Earl Grey
# 4239         Earl Grey
# 4240         Earl Grey
# Name: Product, Length: 4241, dtype: object

# %%
product=Sales['Product']

# %%
product.nunique()
# Out:
# 13

# %%
product.head(20)
# Out:
# 0           Amaretto
# 1          Green Tea
# 2        Caffe Mocha
# 3     Decaf Espresso
# 4          Chamomile
# 5              Lemon
# 6               Mint
# 7         Darjeeling
# 8          Earl Grey
# 9          Columbian
# 10         Columbian
# 11         Columbian
# 12         Green Tea
# 13    Decaf Espresso
# 14    Decaf Espresso
# 15    Decaf Espresso
# 16         Chamomile
# 17             Lemon
# 18             Lemon
# 19              Mint
# Name: Product, dtype: object

# %%
product1=product.head(20)

# %%
product1.nunique()
# Out:
# 10

# %%
fig, ax = plt.subplots(2,figsize =(20,20))     # Create a figure and a grid of subplots with 2 rows
fig.suptitle('Sale/Revenue', fontsize=14, fontweight='bold')  
ax[0].pie(Total_expenses1, labels=product1, autopct="%.2f%%")
ax[1].pie(Total_expenses2, labels=Product_type2, autopct="%.2f%%")
ax[0].set_position([0.1,0.6,0.5,0.2])
ax[1].set_position([0.6,0.6,0.5,0.2])

ax[0].set_title("Total_expenses/product1",fontsize=18,fontweight='bold')
ax[1].set_title("Total_expenses2/Product_type2",fontsize=18,fontweight='bold')

plt.show()
